# %% [markdown]
# <div style="background:#FFFFAA">
# <img src="logo.jpg", width=150, ALIGN="left", border=20>
#     <h1>Team GAIASAVERS</h1>
#     <h3>Alban Petit, Wafa Bouzouita,Timothée Babinet, Maxime Chor, Eric Wang, Sebastien Warichet</h3>
#     <h2>Plankton classification challenge</h2>
#
# <br>This code was tested with <br>
# Python 3.7 |Anaconda custom (64-bit)| (default, Jun 28 2018, 11:07:29) (https://anaconda.org/)<br>
# <i> Adapted for Chalab by Isabelle Guyon from original code of Balázs Kégl</i> <br>
# <a href="http://www.datascience-paris-saclay.fr">Paris Saclay Center for Data Science (CDS)</a>
# </center>
# <p>
# ALL INFORMATION, SOFTWARE, DOCUMENTATION, AND DATA ARE PROVIDED "AS-IS". The CDS, CHALEARN, AND/OR OTHER ORGANIZERS OR CODE AUTHORS DISCLAIM ANY EXPRESSED OR IMPLIED WARRANTIES, INCLUDING, BUT NOT LIMITED TO, THE IMPLIED WARRANTIES OF MERCHANTABILITY AND FITNESS FOR ANY PARTICULAR PURPOSE, AND THE WARRANTY OF NON-INFRIGEMENT OF ANY THIRD PARTY'S INTELLECTUAL PROPERTY RIGHTS. IN NO EVENT SHALL AUTHORS AND ORGANIZERS BE LIABLE FOR ANY SPECIAL,
# INDIRECT OR CONSEQUENTIAL DAMAGES OR ANY DAMAGES WHATSOEVER ARISING OUT OF OR IN CONNECTION WITH THE USE OR PERFORMANCE OF SOFTWARE, DOCUMENTS, MATERIALS, PUBLICATIONS, OR INFORMATION MADE AVAILABLE FOR THE CHALLENGE.
# </div>

# %% [markdown]
# <div style="background:#FFFFAA">
#     <h2>Introduction </h2>
#      <br>
#
# According to [NRMA15], a link has been found between the quality of water and the presence of plankton in said water. As water quality increases, the abundance and diversity of plankton does as well. The aim of our project is to build a plankton classifier to assess water quality.
#
# We use for this problem the Bering Sea dataset, an in situ plankton dataset published in May 2019 by Kaichang Cheng [Che19]. This datset contains 7 classes with an even spread.
#
#
# References and credits:
# - [NRMA15] A. Nair, J.K. Reshma, A. Mathew, and A. Ashok. Effect of water quality on phytoplankton abundance in selected ponds of nedumangad block panchayat, kerala. Emer Life Sci Res, 2015.
# - [Che19] K. Cheng. Bering sea dataset. https://doi.org/10.6084/m9.figshare.8146283.v3, 2019.
#  <br>
# </div>

# %% [markdown]
# <img src="images/sample.png" alt="Drawing"/>
# To see more images for each class, see the "images" folder.

# %%
model_dir = 'sample_code_submission/'                        # Change the model to a better one once you have one!
result_dir = 'sample_result_submission/' 
problem_dir = 'ingestion_program/'  
score_dir = 'scoring_program/'
from sys import path; path.append(model_dir); path.append(problem_dir); path.append(score_dir); 
# %matplotlib inline
# Uncomment the next lines to auto-reload libraries (this causes some problem with pickles in Python 3)
# %load_ext autoreload
# %autoreload 2
import seaborn as sns; sns.set()
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from scipy import stats

# %% [markdown]
# <div style="background:#FFFFAA">
#     <h1> Step 1: Exploratory data analysis </h1>
# <p>
# We provide sample_data with the starting kit, but to prepare your submission, you must fetch the public_data from the challenge website and point to it.
#     <br>
#     <span style="color:red"> Just change the data name in the block below. In the rest of the section, replace the sample plots by anything you want. </span>
# </div>

# %%
#data_dir = 'sample_data'              # Change this to the directory where you put the input data
data_dir = 'public_data'          # The sample_data directory should contain only a very small subset of the data
data_name = 'plankton'
# !ls $data_dir*
# Out:
# plankton_feat.name    plankton_test.data       plankton_valid.data
# plankton_label.name   plankton_train.data
# plankton_public.info  plankton_train.solution

# %% [markdown]
# <h3>Two "feature representation"</h3>
#
# <p>
# 1.
# All of the images are in various shades of gray. As such, we can represent every image by a vector of 90000 (300x300) features where each feature is a float value between 0 and 255 representing the brightness of a pixel (0 being a black pixel and 255 a white one). It is also possible to reduce the size of the images to reduce the number of features as seen in figure 3 where we reduced the size to 100x100 pixels.
# </p>

# %% [markdown]
# <tr>
#     <td> <img src="images/gray.png" alt="Drawing" style="width: 250px;"/> </td>
#     <td> <img src="images/binarized.png" alt="Drawing" style="width: 250px;"/> </td>
# </tr>

# %% [markdown]
# <p>
# 2. At first we will have four types of "features". Two "features" are applied on the binarized images.
#     <ul>
#         <li>The first is a sum of black pixels, per line and per column.
# This gives us 2 vectors of size 100. These "features" are representative among others of the shape of the plankton.
# For round seeders the ratio between rows and columns near the center of the image should be close.
# For longer plankton the ratio will be either low or high, depending on plankton position.
#         </li>
#         <li>The second is the average of the pixels.
#             This gives us information on the size of the plankton.
#         </li>
#         <li>The third feature is the variance and is applied to non-binarized images.</li>
#         <li>The last feature is the length of the contour of the plankton. It is obtained by applying a sobel filter on the image. This filter will put black pixels on the contours and white ones everywhere else. We can then just compute the amount of black pixels.
#     </ul>
# </p>

# %% [markdown]
# For convenience, we load the data as a "pandas" data frame, so we can use "pandas" and "seaborn" built in functions to explore the data.

# %%
from data_io import read_as_df
data = read_as_df(data_dir  + '/' + data_name)                # The data are loaded as a Pandas Data Frame
# Out:
# Reading public_data/plankton_train from AutoML format
# Number of examples = 10752
# Number of features = 203
#           Class
# 0  chaetognatha
# 1      copepoda
# 2   euphausiids
# 3   fish_larvae
# 4      limacina
# 5       medusae
# 6         other
# Number of classes = 7

# %% [markdown]
# This shows the distribution of labels in the training set

# %%
data['target'].value_counts()
# Out:
# copepoda        1536
# euphausiids     1536
# chaetognatha    1536
# other           1536
# limacina        1536
# fish_larvae     1536
# medusae         1536
# Name: target, dtype: int64

# %% [markdown]
# The first rows of the dataset.

# %%
data.head()
# Out:
#    sum_axis_0_0  sum_axis_0_1  sum_axis_0_2  sum_axis_0_3  sum_axis_0_4  \
# 0           1.0           1.0          1.00          1.00          1.00
# 1           1.0           1.0          1.00          1.00          1.00
# 2           1.0           1.0          1.00          1.00          1.00
# 3           1.0           1.0          0.99          0.96          0.94
# 4           1.0           1.0          1.00          1.00          1.00
#
#    sum_axis_0_5  sum_axis_0_6  sum_axis_0_7  sum_axis_0_8  sum_axis_0_9  ...  \
# 0          1.00          1.00          1.00          1.00          1.00  ...
# 1          1.00          1.00          1.00          1.00          1.00  ...
# 2          1.00          1.00          1.00          1.00          1.00  ...
# 3          0.94          0.92          0.92          0.92          0.93  ...
# 4          1.00          1.00          1.00          1.00          1.00  ...
#
#    sum_axis_1_94  sum_axis_1_95  sum_axis_1_96  sum_axis_1_97  sum_axis_1_98  \
# 0        0.83871        0.83871       0.827957       0.817204       0.795699
# 1        1.00000        1.00000       1.000000       1.000000       1.000000
# 2        0.82000        0.90000       1.000000       1.000000       1.000000
# 3        0.96000        0.99000       1.000000       1.000000       1.000000
# 4        1.00000        0.99000       0.990000       0.990000       1.000000
#
#    sum_axis_1_99      mean  variance  outline_length        target
# 0       0.774194  0.744560  0.062088            9.82         other
# 1       1.000000  0.852347  0.021939            0.64         other
# 2       1.000000  0.478031  0.130620            6.68      limacina
# 3       1.000000  0.799294  0.037921            6.86  chaetognatha
# 4       1.000000  0.713423  0.065195           11.56       medusae
#
# [5 rows x 204 columns]

# %% [markdown]
# Some statistics about the features.

# %%
data.describe()
# Out:
#        sum_axis_0_0  sum_axis_0_1  sum_axis_0_2  sum_axis_0_3  sum_axis_0_4  \
# count  10752.000000  10752.000000  10752.000000  10752.000000  10752.000000
# mean       0.979279      0.977036      0.972997      0.965795      0.956058
# std        0.096922      0.098681      0.099546      0.102380      0.106950
# min        0.100000      0.050000      0.070000      0.030000      0.040000
# 25%        1.000000      1.000000      1.000000      0.990000      0.960000
# 50%        1.000000      1.000000      1.000000      1.000000      1.000000
# 75%        1.000000      1.000000      1.000000      1.000000      1.000000
# max        1.000000      1.000000      1.000000      1.000000      1.000000
#
#        sum_axis_0_5  sum_axis_0_6  sum_axis_0_7  sum_axis_0_8  sum_axis_0_9  \
# count  10752.000000  10752.000000  10752.000000  10752.000000  10752.000000
# mean       0.946609      0.938161      0.930047      0.922546      0.914766
# std        0.113165      0.119380      0.126461      0.132001      0.138568
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.940000      0.930000      0.916667      0.900000      0.880000
# 50%        1.000000      1.000000      1.000000      1.000000      1.000000
# 75%        1.000000      1.000000      1.000000      1.000000      1.000000
# max        1.000000      1.000000      1.000000      1.000000      1.000000
#
#        ...  sum_axis_1_93  sum_axis_1_94  sum_axis_1_95  sum_axis_1_96  \
# count  ...   10752.000000   10752.000000   10752.000000   10752.000000
# mean   ...       0.936903       0.943581       0.951833       0.961342
# std    ...       0.118902       0.114981       0.110555       0.106497
# min    ...       0.000000       0.000000       0.000000       0.000000
# 25%    ...       0.920000       0.940000       0.950000       0.980000
# 50%    ...       1.000000       1.000000       1.000000       1.000000
# 75%    ...       1.000000       1.000000       1.000000       1.000000
# max    ...       1.000000       1.000000       1.000000       1.000000
#
#        sum_axis_1_97  sum_axis_1_98  sum_axis_1_99          mean  \
# count   10752.000000   10752.000000   10752.000000  10752.000000
# mean        0.966297       0.970557       0.971949      0.677502
# std         0.105424       0.104636       0.105878      0.133997
# min         0.000000       0.010000       0.040000      0.209394
# 25%         1.000000       1.000000       1.000000      0.582888
# 50%         1.000000       1.000000       1.000000      0.694925
# 75%         1.000000       1.000000       1.000000      0.782364
# max         1.000000       1.000000       1.000000      0.969234
#
#            variance  outline_length
# count  10752.000000    10752.000000
# mean       0.074303        8.117898
# std        0.033898        4.244094
# min        0.001928        0.000000
# 25%        0.049183        5.740000
# 50%        0.068188        6.720000
# 75%        0.094579        9.102500
# max        0.214556       31.030000
#
# [8 rows x 203 columns]

# %%
data[['sum_axis_0_50','sum_axis_1_50','mean','variance', 'outline_length']].hist(figsize=(10, 10), bins=50, layout=(3, 2));

# %%
from sklearn import preprocessing
data_target = data.copy()
le = preprocessing.LabelEncoder()
data_target.target = le.fit_transform(data_target.target.values)
fig = plt.figure(figsize=(15,8))
sns.heatmap(data_target[['sum_axis_0_50','sum_axis_1_50','mean','variance','outline_length','target']].corr(), annot = True)
plt.title('Correlation_matrix')
plt.show()

# %%
sns.pairplot(data,hue='target',vars=['sum_axis_0_50','sum_axis_1_50','mean','variance','outline_length'])
plt.show()

# %% [markdown]
# # Features Selection

# %% [markdown]
# #### Sort features <br />
#
# Let us first sort all features by the <b>absolute value</b> of the Pearson correlation coefficient.

# %%
corr = data_target.corr()
sval = corr['target'][:-1].abs().sort_values(ascending=False)
ranked_columns = sval.index.values
print(ranked_columns[0:75])
# Out:
# ['mean' 'sum_axis_1_79' 'sum_axis_1_80' 'sum_axis_1_78' 'sum_axis_1_77'
#  'sum_axis_1_81' 'sum_axis_1_76' 'sum_axis_1_75' 'sum_axis_1_74'
#  'sum_axis_1_73' 'sum_axis_1_82' 'sum_axis_1_71' 'sum_axis_1_72'
#  'sum_axis_1_69' 'sum_axis_1_70' 'sum_axis_1_68' 'sum_axis_1_67'
#  'sum_axis_1_66' 'sum_axis_0_20' 'sum_axis_0_21' 'sum_axis_1_83'
#  'sum_axis_0_22' 'sum_axis_0_23' 'sum_axis_0_19' 'sum_axis_0_18'
#  'sum_axis_0_24' 'sum_axis_1_65' 'sum_axis_1_64' 'sum_axis_0_26'
#  'sum_axis_0_17' 'sum_axis_0_25' 'sum_axis_0_27' 'sum_axis_1_63'
#  'sum_axis_0_28' 'sum_axis_1_62' 'sum_axis_0_16' 'sum_axis_0_29'
#  'sum_axis_0_31' 'sum_axis_0_30' 'sum_axis_1_61' 'sum_axis_0_32'
#  'sum_axis_0_15' 'sum_axis_1_60' 'sum_axis_0_76' 'sum_axis_1_84'
#  'sum_axis_0_75' 'sum_axis_0_77' 'sum_axis_0_78' 'sum_axis_0_74'
#  'sum_axis_0_33' 'sum_axis_1_59' 'sum_axis_0_73' 'sum_axis_0_79'
#  'sum_axis_0_72' 'sum_axis_0_34' 'sum_axis_0_14' 'sum_axis_1_31'
#  'sum_axis_0_71' 'sum_axis_0_80' 'sum_axis_1_24' 'sum_axis_0_68'
#  'sum_axis_1_30' 'sum_axis_1_26' 'sum_axis_1_32' 'sum_axis_1_23'
#  'sum_axis_0_35' 'sum_axis_0_70' 'sum_axis_1_33' 'sum_axis_1_29'
#  'sum_axis_1_25' 'sum_axis_1_58' 'sum_axis_1_34' 'sum_axis_0_69'
#  'sum_axis_1_35' 'sum_axis_1_28']

# %% [markdown]
# <b>We choose to keep the 50 top most informative features</b>

# %%
col_selected = ranked_columns[0:75]
df_75feat = pd.DataFrame.copy(data_target)
df_75feat = df_75feat[col_selected]
df_75feat['target'] = data_target['target']
df_75feat.head()
# Out:
#        mean  sum_axis_1_79  sum_axis_1_80  sum_axis_1_78  sum_axis_1_77  \
# 0  0.744560       0.924731       0.913978       0.935484       0.956989
# 1  0.852347       1.000000       1.000000       1.000000       1.000000
# 2  0.478031       0.500000       0.510000       0.490000       0.480000
# 3  0.799294       0.900000       0.940000       0.900000       0.910000
# 4  0.713423       0.910000       0.930000       0.890000       0.880000
#
#    sum_axis_1_81  sum_axis_1_76  sum_axis_1_75  sum_axis_1_74  sum_axis_1_73  \
# 0       0.903226       0.946237       0.956989       0.956989       0.956989
# 1       1.000000       1.000000       1.000000       1.000000       1.000000
# 2       0.520000       0.460000       0.460000       0.450000       0.440000
# 3       0.950000       0.910000       0.900000       0.910000       0.910000
# 4       0.940000       0.870000       0.860000       0.850000       0.830000
#
#    ...  sum_axis_0_70  sum_axis_1_33  sum_axis_1_29  sum_axis_1_25  \
# 0  ...           0.92       0.956989       0.978495       0.967742
# 1  ...           1.00       0.980000       0.990000       1.000000
# 2  ...           0.37       0.300000       0.320000       0.340000
# 3  ...           0.88       0.850000       0.860000       0.900000
# 4  ...           0.99       0.880000       0.880000       0.760000
#
#    sum_axis_1_58  sum_axis_1_34  sum_axis_0_69  sum_axis_1_35  sum_axis_1_28  \
# 0       0.989247       0.946237           0.93       0.946237       0.978495
# 1       1.000000       0.990000           1.00       0.990000       1.000000
# 2       0.320000       0.300000           0.34       0.300000       0.320000
# 3       0.890000       0.850000           0.87       0.850000       0.880000
# 4       0.830000       0.890000           0.99       0.870000       0.840000
#
#    target
# 0       6
# 1       6
# 2       4
# 3       0
# 4       5
#
# [5 rows x 76 columns]

# %%
# Show pairplot
g = sns.pairplot(df_75feat, hue='target',vars=ranked_columns[1:75:15])
plt.show()

# %%
def ExtractData(df):
    X = np.array(df.iloc[:,:-1])
    Y = np.array(df.iloc[:,-1])
    Y = Y.reshape(Y.shape[0],1)
    return X,Y

# %%
def featuresSlection(data_target):
    corr = data_target.corr()
    sval = corr['target'][:-1].abs().sort_values(ascending=False)
    ranked_columns = sval.index.values
    col_selected = ranked_columns[0:75]
    df_75feat = pd.DataFrame.copy(data_target)
    df_75feat = df_75feat[col_selected]
    df_75feat['target'] = data_target['target']
    X,Y = ExtractData(df_75feat)
    return X,Y

# %% [markdown]
# # Outliers detection and deletion

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X,Y = ExtractData(df_75feat)
X = scaler.fit_transform(X)
XY = pd.DataFrame(np.append(X, Y, axis=1), columns = df_75feat.columns)
XY
# Out:
#            mean  sum_axis_1_79  sum_axis_1_80  sum_axis_1_78  sum_axis_1_77  \
# 0      0.500468       0.563098       0.486350       0.634020       0.748049
# 1      1.304907       0.905078       0.891757       0.920716       0.935398
# 2     -1.488689      -1.366646      -1.417541      -1.345615      -1.329648
# 3      0.908960       0.450733       0.608985       0.476338       0.543371
# 4      0.268085       0.496168       0.561857       0.431900       0.412695
# ...         ...            ...            ...            ...            ...
# 10747 -1.161878      -3.638371      -3.821097      -3.523070      -3.420461
# 10748 -1.180846      -2.320770      -2.548626      -2.234372      -2.070144
# 10749 -0.179575       0.132692       0.090572      -0.012479      -0.022891
# 10750 -1.445684      -1.366646      -1.276156      -1.301177      -1.286090
# 10751 -0.481272       0.668440       0.695388       0.689269       0.572410
#
#        sum_axis_1_81  sum_axis_1_76  sum_axis_1_75  sum_axis_1_74  \
# 0           0.408814       0.719089       0.782353       0.799908
# 1           0.877632       0.949368       0.963673       0.978763
# 2          -1.447704      -1.363555      -1.312794      -1.308348
# 3           0.635410       0.563880       0.542105       0.604509
# 4           0.586965       0.392553       0.373478       0.355006
# ...              ...            ...            ...            ...
# 10747      -3.966818      -3.333822      -3.252006      -3.179622
# 10748      -2.804150      -1.963202      -1.818675      -1.724187
# 10749       0.150965       0.007066      -0.005933       0.022335
# 10750      -1.205482      -1.277891      -1.270637      -1.308348
# 10751       0.675780       0.503202       0.524539       0.545598
#
#        sum_axis_1_73  ...  sum_axis_0_70  sum_axis_1_33  sum_axis_1_29  \
# 0           0.817827  ...       0.711303       0.917707       0.950426
# 1           0.994885  ...       1.065601       1.012832       0.999698
# 2          -1.310409  ...      -1.724492      -1.798231      -1.869583
# 3           0.624391  ...       0.534154       0.475423       0.442971
# 4           0.295064  ...       1.021313       0.599440       0.528622
# ...              ...  ...            ...            ...            ...
# 10747      -3.121712  ...       0.260379      -0.475378      -0.413530
# 10748      -1.639737  ...      -1.126392       0.516762       0.400146
# 10749       0.048068  ...       0.224144      -0.682074      -0.798956
# 10750      -1.310409  ...      -2.255939      -1.054126      -0.327880
# 10751       0.523192  ...       0.884837      -0.411647       0.641037
#
#        sum_axis_1_25  sum_axis_1_58  sum_axis_1_34  sum_axis_0_69  \
# 0           0.837933       1.178564       0.892142       0.776277
# 1           0.983562       1.220180       1.072021       1.083530
# 2          -1.996023      -1.411637      -1.764056      -1.813425
# 3           0.532110       0.794445       0.496585       0.512918
# 4          -0.099923       0.562226       0.660996       1.039637
# ...              ...            ...            ...            ...
# 10747      -0.280504      -1.837373      -0.613184       0.235592
# 10748       0.306384      -0.405354       0.455483      -1.088964
# 10749      -0.596521       0.252600      -0.736492       0.205665
# 10750      -0.370794      -1.140715      -1.188620      -2.208464
# 10751       0.842483       0.413864      -0.556668       0.814796
#
#        sum_axis_1_35  sum_axis_1_28  target
# 0           0.909412       0.934724     6.0
# 1           1.088238       1.027717     6.0
# 2          -1.731236      -1.912732     4.0
# 3           0.516171       0.508814     0.0
# 4           0.597894       0.335847     5.0
# ...              ...            ...     ...
# 10747      -0.627964      -0.356023     6.0
# 10748       0.434447       0.422331     3.0
# 10749      -0.791411      -0.788442     2.0
# 10750      -1.240892      -0.226298     6.0
# 10751      -0.275529       0.757455     1.0
#
# [10752 rows x 76 columns]

# %% [markdown]
# <b>Visualization of the outliers on the 5 top best features<b/>

# %%
ax = sns.boxplot(data=XY.iloc[:,:5] , orient="h", palette="Set2")

# %%
ax = sns.boxplot(data=XY.iloc[:,-5:-1] , orient="h", palette="Set2")

# %%
ax = sns.boxplot(data=XY, orient="h", palette="Set2")

# %% [markdown]
# <b>To detect outliers we use the IQR</b>

# %%
Q1 = XY.quantile(0.25)
Q3 = XY.quantile(0.75)
IQR = Q3 - Q1
print(IQR)
# Out:
# mean             1.488724
# sum_axis_1_79    1.363035
# sum_axis_1_80    1.394733
# sum_axis_1_78    1.333136
# sum_axis_1_77    1.306758
#                    ...
# sum_axis_1_34    1.233077
# sum_axis_0_69    1.360691
# sum_axis_1_35    1.266720
# sum_axis_1_28    1.254015
# target           4.000000
# Length: 76, dtype: float64

# %% [markdown]
# <br>False means these values are valid and True indicates presence of outlier <br/>
# The data out of delta*IQR are considerated like outliers

# %%
print(XY < (Q1 - 1.5 * IQR)) |(XY > (Q3 + 1.5 * IQR))
# Out:
#         mean  sum_axis_1_79  sum_axis_1_80  sum_axis_1_78  sum_axis_1_77  \
# 0      False          False          False          False          False
# 1      False          False          False          False          False
# 2      False          False          False          False          False
# 3      False          False          False          False          False
# 4      False          False          False          False          False
# ...      ...            ...            ...            ...            ...
# 10747  False           True           True           True           True
# 10748  False          False          False          False          False
# 10749  False          False          False          False          False
# 10750  False          False          False          False          False
# 10751  False          False          False          False          False
#
#        sum_axis_1_81  sum_axis_1_76  sum_axis_1_75  sum_axis_1_74  \
# 0              False          False          False          False
# 1              False          False          False          False
# 2              False          False          False          False
# 3              False          False          False          False
# 4              False          False          False          False
# ...              ...            ...            ...            ...
# 10747           True           True           True           True
# 10748           True          False          False          False
# 10749          False          False          False          False
# 10750          False          False          False          False
# 10751          False          False          False          False
#
#        sum_axis_1_73  ...  sum_axis_0_70  sum_axis_1_33  sum_axis_1_29  \
# 0              False  ...          False          False          False
# 1              False  ...          False          False          False
# 2              False  ...          False          False          False
# 3              False  ...          False          False          False
# 4              False  ...          False          False          False
# ...              ...  ...            ...            ...            ...
# 10747           True  ...          False          False          False
# 10748          False  ...          False          False          False
# 10749          False  ...          False          False          False
# 10750          False  ...          False          False          False
# 10751          False  ...          False          False          False
#
#        sum_axis_1_25  sum_axis_1_58  sum_axis_1_34  sum_axis_0_69  \
# 0              False          False          False          False
# 1              False          False          False          False
# 2              False          False          False          False
# 3              False          False          False          False
# 4              False          False          False          False
# ...              ...            ...            ...            ...
# 10747          False          False          False          False
# 10748          False          False          False          False
# 10749          False          False          False          False
# 10750          False          False          False          False
# 10751          False          False          False          False
#
#        sum_axis_1_35  sum_axis_1_28  target
# 0              False          False   False
# 1              False          False   False
# 2              False          False   False
# 3              False          False   False
# 4              False          False   False
# ...              ...            ...     ...
# 10747          False          False   False
# 10748          False          False   False
# 10749          False          False   False
# 10750          False          False   False
# 10751          False          False   False
#
# [10752 rows x 76 columns]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/ops/__init__.py in na_op(x, y)
#    1253         try:
# -> 1254             result = op(x, y)
#    1255         except TypeError:
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/ops/roperator.py in ror_(left, right)
#      56 def ror_(left, right):
# ---> 57     return operator.or_(right, left)
#      58
#
# TypeError: unsupported operand type(s) for |: 'NoneType' and 'bool'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/ops/__init__.py in na_op(x, y)
#    1268                 try:
# -> 1269                     result = libops.scalar_binop(x, y, op)
#    1270                 except (
#
# pandas/_libs/ops.pyx in pandas._libs.ops.scalar_binop()
#
# ValueError: Does not understand character buffer dtype format string ('?')
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-30d871cf5419> in <module>
# ----> 1 print(XY < (Q1 - 1.5 * IQR)) |(XY > (Q3 + 1.5 * IQR))
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/ops/__init__.py in f(self, other, axis, level, fill_value)
#    1504
#    1505             assert np.ndim(other) == 0
# -> 1506             return self._combine_const(other, op)
#    1507
#    1508     f.__name__ = op_name
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in _combine_const(self, other, func)
#    5401     def _combine_const(self, other, func):
#    5402         assert lib.is_scalar(other) or np.ndim(other) == 0
# -> 5403         return ops.dispatch_to_series(self, other, func)
#    5404
#    5405     def combine(self, other, func, fill_value=None, overwrite=True):
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/ops/__init__.py in dispatch_to_series(left, right, func, str_rep, axis)
#     594         raise NotImplementedError(right)
#     595
# --> 596     new_data = expressions.evaluate(column_op, str_rep, left, right)
#     597
#     598     result = left._constructor(new_data, index=left.index, copy=False)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/computation/expressions.py in evaluate(op, op_str, a, b, use_numexpr, **eval_kwargs)
#     219     use_numexpr = use_numexpr and _bool_arith_check(op_str, a, b)
#     220     if use_numexpr:
# --> 221         return _evaluate(op, op_str, a, b, **eval_kwargs)
#     222     return _evaluate_standard(op, op_str, a, b)
#     223
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/computation/expressions.py in _evaluate_numexpr(op, op_str, a, b, truediv, reversed, **eval_kwargs)
#     125
#     126     if result is None:
# --> 127         result = _evaluate_standard(op, op_str, a, b)
#     128
#     129     return result
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/computation/expressions.py in _evaluate_standard(op, op_str, a, b, **eval_kwargs)
#      68         _store_test_result(False)
#      69     with np.errstate(all="ignore"):
# ---> 70         return op(a, b)
#      71
#      72
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/ops/__init__.py in column_op(a, b)
#     568
#     569         def column_op(a, b):
# --> 570             return {i: func(a.iloc[:, i], b) for i in range(len(a.columns))}
#     571
#     572     elif isinstance(right, ABCDataFrame):
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/ops/__init__.py in <dictcomp>(.0)
#     568
#     569         def column_op(a, b):
# --> 570             return {i: func(a.iloc[:, i], b) for i in range(len(a.columns))}
#     571
#     572     elif isinstance(right, ABCDataFrame):
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/ops/roperator.py in ror_(left, right)
#      55
#      56 def ror_(left, right):
# ---> 57     return operator.or_(right, left)
#      58
#      59
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/ops/__init__.py in wrapper(self, other)
#    1319         #   integer dtypes.  Otherwise these are boolean ops
#    1320         filler = fill_int if is_self_int_dtype and is_other_int_dtype else fill_bool
# -> 1321         res_values = na_op(self.values, ovalues)
#    1322         unfilled = self._constructor(res_values, index=self.index, name=res_name)
#    1323         filled = filler(unfilled)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/ops/__init__.py in na_op(x, y)
#    1278                         "cannot compare a dtyped [{dtype}] array "
#    1279                         "with a scalar of type [{typ}]".format(
# -> 1280                             dtype=x.dtype, typ=type(y).__name__
#    1281                         )
#    1282                     )
#
# TypeError: cannot compare a dtyped [bool] array with a scalar of type [NoneType]

# %% [markdown]
# <b> We write a fonction to supress these Outliers </b>

# %%
from sklearn.preprocessing import StandardScaler

def outliersIQR(X_train, Y_train, StDeviation):
    scaler = StandardScaler()
    X = scaler.fit_transform(X_train)
    XY = pd.DataFrame(np.append(X, Y_train, axis=1))
    #orignaly used with 0.15 et 0.75 but that delete to much data
    Q1 = XY.quantile(0.10)
    Q3 = XY.quantile(0.90)
    IQR = Q3 - Q1
    XY = XY[~((XY < (Q1 - StDeviation * IQR)) |(XY > (Q3 + StDeviation * IQR))).any(axis=1)]
    X,Y = ExtractData(XY)
    print("Number of Data deleted = ", X_train.shape[0]-X.shape[0])
    return X,Y

# %%
from data_manager import DataManager
D = DataManager(data_name, data_dir, replace_missing=True)
fnum = 8
X,Y = outliersIQR(D.data['X_train'], D.data['Y_train'], 3)
# Out:
# Info file found : /home/fenrir/S4/miniprojet/PLANKTON/starting_kit/public_data/plankton_public.info
# Number of Data deleted =  2912

# %%
print("X = ", X.shape , "et Y =", Y.shape)
XY = pd.DataFrame(np.append(X, Y, axis=1), columns = data.columns)
# Out:
# X =  (7840, 203) et Y = (7840, 1)

# %%
sns.pairplot(XY, hue="target", vars=['sum_axis_0_50','sum_axis_1_50','mean','variance','outline_length'])

# %%
ax = sns.boxplot(data=XY.iloc[:,:5] , orient="h", palette="Set2")

# %% [markdown]
# And other method to detect and delete outliers is the <b> Z-score </b>

# %%
X = D.data['X_train']
Y = D.data['Y_train']
scaler = StandardScaler()
X = scaler.fit_transform(X)
XY = pd.DataFrame(np.append(X, Y, axis=1), columns = data.columns)
z = np.abs(stats.zscore(XY))
print(z)
XY = XY[(z < 3).all(axis=1)]
# Out:
# [[0.21380255 0.23272046 0.27127314 ... 0.36035719 0.40107058 1.5       ]
#  [0.21380255 0.23272046 0.27127314 ... 1.5448236  1.762036   1.5       ]
#  [0.21380255 0.23272046 0.27127314 ... 1.66143352 0.33881555 0.5       ]
#  ...
#  [0.21380255 0.23272046 0.27127314 ... 0.15085768 0.16543805 0.5       ]
#  [0.21380255 0.23272046 0.27127314 ... 0.75744333 0.07019447 1.5       ]
#  [0.21380255 0.23272046 0.1687619  ... 0.79944131 0.3563004  1.        ]]

# %%
def outliersZScore(X_train, Y_train, StDeviation):
    XY_train = pd.DataFrame(np.append(X_train, Y_train, axis=1))#, columns = data.columns)
    XY_train = XY_train[(np.abs(stats.zscore(XY_train)) < StDeviation).all(axis=1)]
    Y = np.array(XY_train.iloc[:,-1])
    Y = Y.reshape(Y.shape[0],1)
    X = X_train[(np.abs(stats.zscore(X_train)) < StDeviation).all(axis=1)]
    print("Number of Data after outliers deletion = ", X_train.shape[0]-X.shape[0])
    return X,Y

# %%
X,Y = outliersZScore(D.data['X_train'], D.data['Y_train'], 3)
XY = pd.DataFrame(np.append(X, Y, axis=1), columns = data.columns)
# Out:
# Number of Data after outliers deletion =  1747

# %%
sns.pairplot(XY, hue="target", vars=['sum_axis_0_50','sum_axis_1_50','mean','variance','outline_length'])

# %%
ax = sns.boxplot(data=XY.iloc[:,:5] , orient="h", palette="Set2")

# %% [markdown]
# <b> The method based on the IQR seems to be better to deleted Features but he delete maybe too much data, we will use the Z-score or Choose other parameters for the IQR method </b>

# %% [markdown]
# # Dimension Reduction Using PCA

# %%
from sklearn.decomposition import PCA

def dimensionReduction(X_train, fnum):
    labels= ['SV'+str(i) for i in range(1,fnum+1)]
    labels.append("target")
    X = PCA(n_components=fnum).fit_transform(X_train)
    return X, labels

# %% [markdown]
# Actually we will used previous data with features selection and outliers deletion

# %%
fnum = 10
X, labels = dimensionReduction(X, fnum)
X.shape
# Out:
# (9005, 10)

# %%
XY = pd.DataFrame(np.append(X, Y, axis=1), columns = labels)
XY.head()
# Out:
#         SV1       SV2       SV3       SV4       SV5       SV6       SV7  \
# 0  1.881932 -2.450616  0.400019  0.505401 -0.208044 -0.357367 -0.171701
# 1 -7.262395 -1.030742 -0.108377  0.623264  0.191861  0.093909  0.029512
# 2  0.821760  5.211479  1.256162  0.455475 -0.373729  0.196699 -0.558730
# 3 -0.957861 -1.610469 -0.110412  0.370197  0.092555  0.151268  0.022663
# 4  3.743786 -2.192202  0.303426  0.352755 -0.493195 -0.406735  0.071533
#
#         SV8       SV9      SV10  target
# 0  0.019642  0.053825 -0.246252     6.0
# 1 -0.055961 -0.002444 -0.005884     6.0
# 2  0.195079 -0.055118  0.130769     4.0
# 3 -0.037323  0.127338 -0.129738     0.0
# 4 -0.300199  0.275377  0.259069     5.0

# %%
g = sns.pairplot(XY, hue="target", vars=["SV1", "SV2", "SV3"], diag_kind="hist")

# %% [markdown]
# <div style="background:#FFFFAA">
#     <h2>Loading data with DataManager</h2>
#     <p>
# We reload the data with the AutoML DataManager class because this is more convenient:
# </div>

# %%
from data_manager import DataManager
D = DataManager(data_name, data_dir, replace_missing=True)
print(D)
# Out:
# Info file found : /home/fenrir/S4/miniprojet/PLANKTON/starting_kit/public_data/plankton_public.info
# DataManager : plankton
# info:
# 	usage = Sample dataset plankton data
# 	name = plankton
# 	task = multiclass.classification
# 	target_type = Numerical
# 	feat_type = Numerical
# 	metric = bac_metric
# 	time_budget = 1200
# 	feat_num = 202
# 	target_num = 7
# 	label_num = 7
# 	train_num = 10752
# 	valid_num = 3584
# 	test_num = 3584
# 	has_categorical = 0
# 	has_missing = 0
# 	is_sparse = 0
# 	format = dense
# data:
# 	X_train = array(10752, 203)
# 	Y_train = array(10752, 1)
# 	X_valid = array(3584, 203)
# 	Y_valid = array(0,)
# 	X_test = array(3584, 203)
# 	Y_test = array(0,)
# feat_type:	array(202,)
# feat_idx:	array(0,)

# %% [markdown]
# <div style="background:#FFFFAA">
#     <h2>Training a predictive model</h2>
#     <p>
# We provide an example of predictive model (for classification or regression) in the `sample_code_submission/` directory. It is a quite stupid model: it makes constant predictions. Replace it with your own model.
#     </div>

# %%
from data_io import write
from model import model

# %% [markdown]
# <div style="background:#FFFFAA">
# an instance of the model (run the constructor) and attempt to reload a previously saved version from `sample_code_submission/`:
#
# </div>

# %%
# uncomment the desired model

# Decision tree model
from sklearn.tree import DecisionTreeClassifier
M = model(classifier=DecisionTreeClassifier(max_depth=10, max_features = 'sqrt',random_state=42))

trained_model_name = model_dir + data_name

# Uncomment the next line to re-load an already trained model
#M = model()
#M = M.load(trained_model_name)

# %% [markdown]
# <div style="background:#FFFFAA">
#     Train the model (unless you reloaded a trained model) and make predictions.
# </div>

# %%
X_train = D.data['X_train']
Y_train = D.data['Y_train']

if not(M.is_trained):
    M.fit(X_train, Y_train)
    print('training')

Y_hat_train = M.predict(D.data['X_train']) # Optional, not really needed to test on training examples
Y_hat_valid = M.predict(D.data['X_valid'])
Y_hat_test = M.predict(D.data['X_test'])
# Out:
# FIT: dim(X)= [10752, 203]
# FIT: dim(y)= [10752, 1]
# training
# PREDICT: dim(X)= [10752, 203]
# PREDICT: dim(y)= [10752, 1]
# PREDICT: dim(X)= [3584, 203]
# PREDICT: dim(y)= [3584, 1]
# PREDICT: dim(X)= [3584, 203]
# PREDICT: dim(y)= [3584, 1]

# %%
def preprocessingFunc(fnum, StDeviation):
    M = model(classifier=DecisionTreeClassifier(max_depth=10, max_features = 'sqrt',random_state=42))

    data_target = read_as_df(data_dir  + '/' + data_name)
    data_target.target = le.fit_transform(data_target.target.values)

    trained_model_name = model_dir + data_name
    
    #X_train,Y_train = featuresSlection(data_target)
    X_train,Y_train = outliersZScore(D.data['X_train'], D.data['Y_train'], StDeviation)
    #X_train,Y_train = outliersZScore(X_train,Y_train, StDeviation)
    #X_train,Y_train = outliersIQR(X_train,Y_train, StDeviation)
    #X_train = dimensionReduction(X_train, fnum)
    X_train = PCA(n_components=fnum).fit_transform(X_train)
    X_test = PCA(n_components=fnum).fit_transform(D.data['X_test'])
    X_valid = PCA(n_components=fnum).fit_transform(D.data['X_valid'])
    
    if not(M.is_trained):
        M.fit(X_train, Y_train)

    Y_hat_train = M.predict(X_train) # Optional, not really needed to test on training examples
    Y_hat_valid = M.predict(X_valid)
    Y_hat_test = M.predict(X_test)
    M.save(trained_model_name)                 
    result_name = result_dir + data_name
    
    return Y_train, Y_hat_train

# %% [markdown]
# <div style="background:#FFFFAA">
#     <b> Save the trained model </b> (will be ready to reload next time around) and save the prediction results. IMPORTANT: if you save the trained model, it will be bundled with your sample code submission. Therefore your model will NOT be retrained on the challenge platform. Remove the pickle from the submission if you want the model to be retrained on the platform.
# </div>

# %%
#choose the best numer of feature
from libscores import get_metric
sc = []

for i in range(2,22,1):
    if(i>10):
        i+=10
    Y_train, Y_hat_train = preprocessingFunc(i, 2.3)
    metric_name, scoring_function = get_metric()
    # Uncomment the next line to display the code of the scoring metric
    #??scoring_function
    sc.append(scoring_function(Y_train, Y_hat_train))
# Out:
# Reading public_data/plankton_train from AutoML format
# Number of examples = 10752
# Number of features = 203
#           Class
# 0  chaetognatha
# 1      copepoda
# 2   euphausiids
# 3   fish_larvae
# 4      limacina
# 5       medusae
# 6         other
# Number of classes = 7
# Number of Data after outliers deletion =  3518
# FIT: dim(X)= [7234, 2]
# FIT: dim(y)= [7234, 1]
# PREDICT: dim(X)= [7234, 2]
# PREDICT: dim(y)= [7234, 1]
# PREDICT: dim(X)= [3584, 2]
# PREDICT: dim(y)= [3584, 1]
# PREDICT: dim(X)= [3584, 2]
# PREDICT: dim(y)= [3584, 1]
# Reading public_data/plankton_train from AutoML format
# Number of examples = 10752
# Number of features = 203
#           Class
# 0  chaetognatha
# 1      copepoda
# 2   euphausiids
# 3   fish_larvae
# 4      limacina
# 5       medusae
# 6         other
# Number of classes = 7
# Number of Data after outliers deletion =  3518
# FIT: dim(X)= [7234, 3]
# FIT: dim(y)= [7234, 1]
# PREDICT: dim(X)= [7234, 3]
# PREDICT: dim(y)= [7234, 1]
# PREDICT: dim(X)= [3584, 3]
# PREDICT: dim(y)= [3584, 1]
# PREDICT: dim(X)= [3584, 3]
# PREDICT: dim(y)= [3584, 1]
# Reading public_data/plankton_train from AutoML format
# Number of examples = 10752
# Number of features = 203
#           Class
# 0  chaetognatha
# 1      copepoda
# 2   euphausiids
# 3   fish_larvae
# 4      limacina
# 5       medusae
# 6         other
# Number of classes = 7
# Number of Data after outliers deletion =  3518
# FIT: dim(X)= [7234, 4]
# FIT: dim(y)= [7234, 1]
# PREDICT: dim(X)= [7234, 4]
# PREDICT: dim(y)= [7234, 1]
# PREDICT: dim(X)= [3584, 4]
# PREDICT: dim(y)= [3584, 1]
# PREDICT: dim(X)= [3584, 4]
# PREDICT: dim(y)= [3584, 1]
# Reading public_data/plankton_train from AutoML format
# Number of examples = 10752
# Number of features = 203
#           Class
# 0  chaetognatha
# 1      copepoda
# 2   euphausiids
# 3   fish_larvae
# 4      limacina
# 5       medusae
# 6         other
# Number of classes = 7
# Number of Data after outliers deletion =  3518
# FIT: dim(X)= [7234, 5]
# FIT: dim(y)= [7234, 1]
# PREDICT: dim(X)= [7234, 5]
# PREDICT: dim(y)= [7234, 1]
# PREDICT: dim(X)= [3584, 5]
# PREDICT: dim(y)= [3584, 1]
# PREDICT: dim(X)= [3584, 5]
# PREDICT: dim(y)= [3584, 1]
# Reading public_data/plankton_train from AutoML format
# Number of examples = 10752
# Number of features = 203
#           Class
# 0  chaetognatha
# 1      copepoda
# 2   euphausiids
# 3   fish_larvae
# 4      limacina
# 5       medusae
# 6         other
# Number of classes = 7
# Number of Data after outliers deletion =  3518
# FIT: dim(X)= [7234, 6]
# FIT: dim(y)= [7234, 1]
# PREDICT: dim(X)= [7234, 6]
# PREDICT: dim(y)= [7234, 1]
# PREDICT: dim(X)= [3584, 6]
# PREDICT: dim(y)= [3584, 1]
# PREDICT: dim(X)= [3584, 6]
# PREDICT: dim(y)= [3584, 1]
# Reading public_data/plankton_train from AutoML format
# Number of examples = 10752
# Number of features = 203
#           Class
# 0  chaetognatha
# 1      copepoda
# 2   euphausiids
# 3   fish_larvae
# 4      limacina
# 5       medusae
# 6         other
# Number of classes = 7
# Number of Data after outliers deletion =  3518
# FIT: dim(X)= [7234, 7]
# FIT: dim(y)= [7234, 1]
# PREDICT: dim(X)= [7234, 7]
# PREDICT: dim(y)= [7234, 1]
# PREDICT: dim(X)= [3584, 7]
# PREDICT: dim(y)= [3584, 1]
# PREDICT: dim(X)= [3584, 7]
# PREDICT: dim(y)= [3584, 1]
# Reading public_data/plankton_train from AutoML format
# Number of examples = 10752
# Number of features = 203
#           Class
# 0  chaetognatha
# 1      copepoda
# 2   euphausiids
# 3   fish_larvae
# 4      limacina
# 5       medusae
# 6         other
# Number of classes = 7
# Number of Data after outliers deletion =  3518
# FIT: dim(X)= [7234, 8]
# FIT: dim(y)= [7234, 1]
# PREDICT: dim(X)= [7234, 8]
# PREDICT: dim(y)= [7234, 1]
# PREDICT: dim(X)= [3584, 8]
# PREDICT: dim(y)= [3584, 1]
# PREDICT: dim(X)= [3584, 8]
# PREDICT: dim(y)= [3584, 1]
# Reading public_data/plankton_train from AutoML format
# Number of examples = 10752
# Number of features = 203
#           Class
# 0  chaetognatha
# 1      copepoda
# 2   euphausiids
# 3   fish_larvae
# 4      limacina
# 5       medusae
# 6         other
# Number of classes = 7
# Number of Data after outliers deletion =  3518
# FIT: dim(X)= [7234, 9]
# FIT: dim(y)= [7234, 1]
# PREDICT: dim(X)= [7234, 9]
# PREDICT: dim(y)= [7234, 1]
# PREDICT: dim(X)= [3584, 9]
# PREDICT: dim(y)= [3584, 1]
# PREDICT: dim(X)= [3584, 9]
# PREDICT: dim(y)= [3584, 1]
# Reading public_data/plankton_train from AutoML format
# Number of examples = 10752
# Number of features = 203
#           Class
# 0  chaetognatha
# 1      copepoda
# 2   euphausiids
# 3   fish_larvae
# 4      limacina
# 5       medusae
# 6         other
# Number of classes = 7
# Number of Data after outliers deletion =  3518
# FIT: dim(X)= [7234, 10]
# FIT: dim(y)= [7234, 1]
# PREDICT: dim(X)= [7234, 10]
# PREDICT: dim(y)= [7234, 1]
# PREDICT: dim(X)= [3584, 10]
# PREDICT: dim(y)= [3584, 1]
# PREDICT: dim(X)= [3584, 10]
# PREDICT: dim(y)= [3584, 1]
# Reading public_data/plankton_train from AutoML format
# Number of examples = 10752
# Number of features = 203
#           Class
# 0  chaetognatha
# 1      copepoda
# 2   euphausiids
# 3   fish_larvae
# 4      limacina
# 5       medusae
# 6         other
# Number of classes = 7
# Number of Data after outliers deletion =  3518
# FIT: dim(X)= [7234, 21]
# FIT: dim(y)= [7234, 1]
# PREDICT: dim(X)= [7234, 21]
# PREDICT: dim(y)= [7234, 1]
# PREDICT: dim(X)= [3584, 21]
# PREDICT: dim(y)= [3584, 1]
# PREDICT: dim(X)= [3584, 21]
# PREDICT: dim(y)= [3584, 1]
# Reading public_data/plankton_train from AutoML format
# Number of examples = 10752
# Number of features = 203
#           Class
# 0  chaetognatha
# 1      copepoda
# 2   euphausiids
# 3   fish_larvae
# 4      limacina
# 5       medusae
# 6         other
# Number of classes = 7
# Number of Data after outliers deletion =  3518
# FIT: dim(X)= [7234, 22]
# FIT: dim(y)= [7234, 1]
# PREDICT: dim(X)= [7234, 22]
# PREDICT: dim(y)= [7234, 1]
# PREDICT: dim(X)= [3584, 22]
# PREDICT: dim(y)= [3584, 1]
# PREDICT: dim(X)= [3584, 22]
# PREDICT: dim(y)= [3584, 1]
# Reading public_data/plankton_train from AutoML format
# Number of examples = 10752
# Number of features = 203
#           Class
# 0  chaetognatha
# 1      copepoda
# 2   euphausiids
# 3   fish_larvae
# 4      limacina
# 5       medusae
# 6         other
# Number of classes = 7
# Number of Data after outliers deletion =  3518
# FIT: dim(X)= [7234, 23]
# FIT: dim(y)= [7234, 1]
# PREDICT: dim(X)= [7234, 23]
# PREDICT: dim(y)= [7234, 1]
# PREDICT: dim(X)= [3584, 23]
# PREDICT: dim(y)= [3584, 1]
# PREDICT: dim(X)= [3584, 23]
# PREDICT: dim(y)= [3584, 1]
# Reading public_data/plankton_train from AutoML format
# Number of examples = 10752
# Number of features = 203
#           Class
# 0  chaetognatha
# 1      copepoda
# 2   euphausiids
# 3   fish_larvae
# 4      limacina
# 5       medusae
# 6         other
# Number of classes = 7
# Number of Data after outliers deletion =  3518
# FIT: dim(X)= [7234, 24]
# FIT: dim(y)= [7234, 1]
# PREDICT: dim(X)= [7234, 24]
# PREDICT: dim(y)= [7234, 1]
# PREDICT: dim(X)= [3584, 24]
# PREDICT: dim(y)= [3584, 1]
# PREDICT: dim(X)= [3584, 24]
# PREDICT: dim(y)= [3584, 1]
# Reading public_data/plankton_train from AutoML format
# Number of examples = 10752
# Number of features = 203
#           Class
# 0  chaetognatha
# 1      copepoda
# 2   euphausiids
# 3   fish_larvae
# 4      limacina
# 5       medusae
# 6         other
# Number of classes = 7
# Number of Data after outliers deletion =  3518
# FIT: dim(X)= [7234, 25]
# FIT: dim(y)= [7234, 1]
# PREDICT: dim(X)= [7234, 25]
# PREDICT: dim(y)= [7234, 1]
# PREDICT: dim(X)= [3584, 25]
# PREDICT: dim(y)= [3584, 1]
# PREDICT: dim(X)= [3584, 25]
# PREDICT: dim(y)= [3584, 1]
# Reading public_data/plankton_train from AutoML format
# Number of examples = 10752
# Number of features = 203
#           Class
# 0  chaetognatha
# 1      copepoda
# 2   euphausiids
# 3   fish_larvae
# 4      limacina
# 5       medusae
# 6         other
# Number of classes = 7
# Number of Data after outliers deletion =  3518
# FIT: dim(X)= [7234, 26]
# FIT: dim(y)= [7234, 1]
# PREDICT: dim(X)= [7234, 26]
# PREDICT: dim(y)= [7234, 1]
# PREDICT: dim(X)= [3584, 26]
# PREDICT: dim(y)= [3584, 1]
# PREDICT: dim(X)= [3584, 26]
# PREDICT: dim(y)= [3584, 1]
# Reading public_data/plankton_train from AutoML format
# Number of examples = 10752
# Number of features = 203
#           Class
# 0  chaetognatha
# 1      copepoda
# 2   euphausiids
# 3   fish_larvae
# 4      limacina
# 5       medusae
# 6         other
# Number of classes = 7
# Number of Data after outliers deletion =  3518
# FIT: dim(X)= [7234, 27]
# FIT: dim(y)= [7234, 1]
# PREDICT: dim(X)= [7234, 27]
# PREDICT: dim(y)= [7234, 1]
# PREDICT: dim(X)= [3584, 27]
# PREDICT: dim(y)= [3584, 1]
# PREDICT: dim(X)= [3584, 27]
# PREDICT: dim(y)= [3584, 1]
# Reading public_data/plankton_train from AutoML format
# Number of examples = 10752
# Number of features = 203
#           Class
# 0  chaetognatha
# 1      copepoda
# 2   euphausiids
# 3   fish_larvae
# 4      limacina
# 5       medusae
# 6         other
# Number of classes = 7
# Number of Data after outliers deletion =  3518
# FIT: dim(X)= [7234, 28]
# FIT: dim(y)= [7234, 1]
# PREDICT: dim(X)= [7234, 28]
# PREDICT: dim(y)= [7234, 1]
# PREDICT: dim(X)= [3584, 28]
# PREDICT: dim(y)= [3584, 1]
# PREDICT: dim(X)= [3584, 28]
# PREDICT: dim(y)= [3584, 1]
# Reading public_data/plankton_train from AutoML format
# Number of examples = 10752
# Number of features = 203
#           Class
# 0  chaetognatha
# 1      copepoda
# 2   euphausiids
# 3   fish_larvae
# 4      limacina
# 5       medusae
# 6         other
# Number of classes = 7
# Number of Data after outliers deletion =  3518
# FIT: dim(X)= [7234, 29]
# FIT: dim(y)= [7234, 1]
# PREDICT: dim(X)= [7234, 29]
# PREDICT: dim(y)= [7234, 1]
# PREDICT: dim(X)= [3584, 29]
# PREDICT: dim(y)= [3584, 1]
# PREDICT: dim(X)= [3584, 29]
# PREDICT: dim(y)= [3584, 1]
# Reading public_data/plankton_train from AutoML format
# Number of examples = 10752
# Number of features = 203
#           Class
# 0  chaetognatha
# 1      copepoda
# 2   euphausiids
# 3   fish_larvae
# 4      limacina
# 5       medusae
# 6         other
# Number of classes = 7
# Number of Data after outliers deletion =  3518
# FIT: dim(X)= [7234, 30]
# FIT: dim(y)= [7234, 1]
# PREDICT: dim(X)= [7234, 30]
# PREDICT: dim(y)= [7234, 1]
# PREDICT: dim(X)= [3584, 30]
# PREDICT: dim(y)= [3584, 1]
# PREDICT: dim(X)= [3584, 30]
# PREDICT: dim(y)= [3584, 1]
# Reading public_data/plankton_train from AutoML format
# Number of examples = 10752
# Number of features = 203
#           Class
# 0  chaetognatha
# 1      copepoda
# 2   euphausiids
# 3   fish_larvae
# 4      limacina
# 5       medusae
# 6         other
# Number of classes = 7
# Number of Data after outliers deletion =  3518
# FIT: dim(X)= [7234, 31]
# FIT: dim(y)= [7234, 1]
# PREDICT: dim(X)= [7234, 31]
# PREDICT: dim(y)= [7234, 1]
# PREDICT: dim(X)= [3584, 31]
# PREDICT: dim(y)= [3584, 1]
# PREDICT: dim(X)= [3584, 31]
# PREDICT: dim(y)= [3584, 1]

# %%
max(sc)
sc
# Out:
# [0.6597532727110688,
#  0.6613633949705283,
#  0.7314011245389673,
#  0.689821063182278,
#  0.6829479733208303,
#  0.6338388863909217,
#  0.670673208075593,
#  0.7141568515221819,
#  0.6727146920450214,
#  0.6628528571582983,
#  0.6195366056773169,
#  0.6091714455048175,
#  0.6306808218071563,
#  0.6758536574818466,
#  0.6418970878157422,
#  0.6548897346865798,
#  0.6607378689008645,
#  0.6398648044510021,
#  0.6443478359867248,
#  0.6142789505190758]

# %%
Y_train, Y_hat_train = preprocessingFunc(4,2.3)
# Out:
# Reading public_data/plankton_train from AutoML format
# Number of examples = 10752
# Number of features = 203
#           Class
# 0  chaetognatha
# 1      copepoda
# 2   euphausiids
# 3   fish_larvae
# 4      limacina
# 5       medusae
# 6         other
# Number of classes = 7
# Number of Data after outliers deletion =  3518
# FIT: dim(X)= [7234, 4]
# FIT: dim(y)= [7234, 1]
# PREDICT: dim(X)= [7234, 4]
# PREDICT: dim(y)= [7234, 1]
# PREDICT: dim(X)= [3584, 4]
# PREDICT: dim(y)= [3584, 1]
# PREDICT: dim(X)= [3584, 4]
# PREDICT: dim(y)= [3584, 1]

# %%
M.save(trained_model_name)                 
result_name = result_dir + data_name
from data_io import write
write(result_name + '_train.predict', Y_hat_train)
write(result_name + '_valid.predict', Y_hat_valid)
write(result_name + '_test.predict', Y_hat_test)
# !ls $result_name*
# Out:
# sample_result_submission/plankton_test.predict
# sample_result_submission/plankton_train.predict
# sample_result_submission/plankton_valid.predict

# %% [markdown]
# <div style="background:#FFFFAA">
#     <h2>Scoring the results</h2>
#     <h3>Load the challenge metric</h3>
#     <p>
# <b>The metric chosen for your challenge</b> is identified in the "metric.txt" file found in the `scoring_function/` directory. The function "get_metric" searches first for a metric having that name in my_metric.py, then in libscores.py, then in sklearn.metric.
#     </div>

# %% [markdown]
# <div style="background:#FFFFAA">
# The chosen metric is the balanced accuracy. It computes the proportion of elements correctly predicted for each class. It then returns the mean of these values. The advantage of this metric is that every class is given an equal weight. <br> In our case, since all the classes are perfectly balanced, it is equivalent to simply computing the accuracy score but it the case the test set is changed and is no longer balanced, the balanced accuracy will still work properly while the accuracy score will not.
# </div>

# %%
from libscores import get_metric
metric_name, scoring_function = get_metric()
print('Using scoring metric:', metric_name)
# Uncomment the next line to display the code of the scoring metric
#??scoring_function
# Out:
# Using scoring metric: balanced_accuracy_score

# %% [markdown]
# <div style="background:#FFFFAA">
#     <h3> Training performance </h3>
#     <p>
# The participants normally posess target values (labels) only for training examples (except for the sample data). We compute with the `example` metric the training score, which should be zero for perfect predictions.
#         </div>

# %%
print('Training score for the', metric_name, 'metric = %5.4f' % scoring_function(Y_train, Y_hat_train))
print('Ideal score for the', metric_name, 'metric = %5.4f' % scoring_function(Y_train, Y_train))
# Out:
# Training score for the balanced_accuracy_score metric = 0.7314
# Ideal score for the balanced_accuracy_score metric = 1.0000

# %% [markdown]
# You can add here other scores and result visualization.

# %%
from sklearn.metrics import confusion_matrix
import numpy as np
import matplotlib.pyplot as plt

plt.style.use('default')
labels = ["chaetognatha","copepoda","euphausiids","fish_larvae","limacina","medusae","other"]
cm = confusion_matrix(Y_train, Y_hat_train)
cm = cm.astype('float') / cm.sum(axis=1)[:,np.newaxis]
fig, ax = plt.subplots(figsize=(8,8))
im = ax.imshow(cm, interpolation='nearest',cmap=plt.cm.Blues)
ax.figure.colorbar(im, ax=ax)
ax.set(xticks=np.arange(cm.shape[1]),yticks=np.arange(cm.shape[0]),xticklabels=labels,yticklabels=labels,title="Confusion matrix",xlabel="Predicted label",ylabel="True label")
plt.setp(ax.get_xticklabels(), rotation=45, ha="right", rotation_mode="anchor")
fmt = '.2f'
thresh = cm.max()/2.
for i in range(cm.shape[0]):
    for j in range(cm.shape[1]):
        ax.text(j, i, format(cm[i, j], fmt),
                ha="center", va="center",
                color="white" if cm[i, j] > thresh else "black")
fig.tight_layout()

# %% [markdown]
# <div style="background:#FFFFAA">
#     <h3>Cross-validation performance</h3>
#     <p>
# The participants do not have access to the labels Y_valid and Y_test to self-assess their validation and test performances. But training performance is not a good prediction of validation or test performance. Using cross-validation, the training data is split into multiple training/test folds, which allows participants to self-assess their model during development. The average CV result and 95% confidence interval is displayed.
#    </div>

# %%
from sklearn.metrics import make_scorer
from sklearn.model_selection import cross_val_score
scores = cross_val_score(M, X_train, Y_train, cv=5, scoring=make_scorer(scoring_function))
print('\nCV score (95 perc. CI): %0.2f (+/- %0.2f)' % (scores.mean(), scores.std() * 2))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-47-09c6442688d8> in <module>
#       1 from sklearn.metrics import make_scorer
#       2 from sklearn.model_selection import cross_val_score
# ----> 3 scores = cross_val_score(M, X_train, Y_train, cv=5, scoring=make_scorer(scoring_function))
#       4 print('\nCV score (95 perc. CI): %0.2f (+/- %0.2f)' % (scores.mean(), scores.std() * 2))
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_validation.py in cross_val_score(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch, error_score)
#     389                                 fit_params=fit_params,
#     390                                 pre_dispatch=pre_dispatch,
# --> 391                                 error_score=error_score)
#     392     return cv_results['test_score']
#     393
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_validation.py in cross_validate(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch, return_train_score, return_estimator, error_score)
#     215
#     216     """
# --> 217     X, y, groups = indexable(X, y, groups)
#     218
#     219     cv = check_cv(cv, y, classifier=is_classifier(estimator))
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py in indexable(*iterables)
#     228         else:
#     229             result.append(np.array(X))
# --> 230     check_consistent_length(*result)
#     231     return result
#     232
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py in check_consistent_length(*arrays)
#     203     if len(uniques) > 1:
#     204         raise ValueError("Found input variables with inconsistent numbers of"
# --> 205                          " samples: %r" % [int(l) for l in lengths])
#     206
#     207
#
# ValueError: Found input variables with inconsistent numbers of samples: [10752, 7234]

# %% [markdown]
# <div style="background:#FFFFAA">
# <h1> Step 3: Making a submission </h1>
#
# <h2> Unit testing </h2>
#
# It is <b><span style="color:red">important that you test your submission files before submitting them</span></b>. All you have to do to make a submission is modify the file <code>model.py</code> in the <code>sample_code_submission/</code> directory, then run this test to make sure everything works fine. This is the actual program that will be run on the server to test your submission.
# <br>
# Keep the sample code simple.
# </div>

# %%
# !source activate python3; python $problem_dir/ingestion.py $data_dir $result_dir $problem_dir $model_dir

# %% [markdown]
# <div style="background:#FFFFAA">
# Also test the scoring program:
#     </div>

# %%
scoring_output_dir = 'scoring_output'
# !source activate python3; python $score_dir/score.py $data_dir $result_dir $scoring_output_dir

# %% [markdown]
# <div style="background:#FFFFAA">
#     <h1> Preparing the submission </h1>
#
# Zip the contents of `sample_code_submission/` (without the directory), or download the challenge public_data and run the command in the previous cell, after replacing sample_data by public_data.
# Then zip the contents of `sample_result_submission/` (without the directory).
# <b><span style="color:red">Do NOT zip the data with your submissions</span></b>.

# %%
import datetime 
from data_io import zipdir
the_date = datetime.datetime.now().strftime("%y-%m-%d-%H-%M")
sample_code_submission = './sample_code_submission_' + the_date + '.zip'
sample_result_submission = './sample_result_submission_' + the_date + '.zip'
zipdir(sample_code_submission, model_dir)
zipdir(sample_result_submission, result_dir)
print("Submit one of these files:\n" + sample_code_submission + "\n" + sample_result_submission)
